# %% [markdown]
# <a href="https://colab.research.google.com/github/wkkw0203/pyton_data_science_bootcamp/blob/main/google_app_store.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://storage.googleapis.com/esmartdata-courses-files/ds-bootcamp/appstore_games.csv'
df_raw = pd.read_csv(url)
df_raw.head()
# Out:
#                                                  URL         ID  \
# 0   https://apps.apple.com/us/app/sudoku/id284921427  284921427
# 1  https://apps.apple.com/us/app/reversi/id284926400  284926400
# 2  https://apps.apple.com/us/app/morocco/id284946595  284946595
# 3  https://apps.apple.com/us/app/sudoku-free/id28...  285755462
# 4  https://apps.apple.com/us/app/senet-deluxe/id2...  285831220
#
#             Name Subtitle                                           Icon URL  \
# 0         Sudoku      NaN  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 1        Reversi      NaN  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 2        Morocco      NaN  https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# 3  Sudoku (Free)      NaN  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 4   Senet Deluxe      NaN  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
#
#    Average User Rating  User Rating Count  Price In-app Purchases  \
# 0                  4.0             3553.0   2.99              NaN
# 1                  3.5              284.0   1.99              NaN
# 2                  3.0             8376.0   0.00              NaN
# 3                  3.5           190394.0   0.00              NaN
# 4                  3.5               28.0   2.99              NaN
#
#                                          Description  \
# 0  Join over 21,000,000 of our fans and download ...
# 1  The classic game of Reversi, also known as Oth...
# 2  Play the classic strategy game Othello (also k...
# 3  Top 100 free app for over a year.\nRated "Best...
# 4  "Senet Deluxe - The Ancient Game of Life and A...
#
#                   Developer Age Rating  \
# 0  Mighty Mighty Good Games         4+
# 1          Kiss The Machine         4+
# 2               Bayou Games         4+
# 3  Mighty Mighty Good Games         4+
# 4           RoGame Software         4+
#
#                                            Languages        Size  \
# 0  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...  15853568.0
# 1                                                 EN  12328960.0
# 2                                                 EN    674816.0
# 3  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...  21552128.0
# 4  DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...  34689024.0
#
#   Primary Genre                             Genres Original Release Date  \
# 0         Games            Games, Strategy, Puzzle            11/07/2008
# 1         Games             Games, Strategy, Board            11/07/2008
# 2         Games             Games, Board, Strategy            11/07/2008
# 3         Games            Games, Strategy, Puzzle            23/07/2008
# 4         Games  Games, Strategy, Board, Education            18/07/2008
#
#   Current Version Release Date
# 0                   30/05/2017
# 1                   17/05/2018
# 2                    5/09/2017
# 3                   30/05/2017
# 4                   22/07/2018

# %%
df_raw.T
# Out:
#                                                                           0      \
# URL                            https://apps.apple.com/us/app/sudoku/id284921427
# ID                                                                    284921427
# Name                                                                     Sudoku
# Subtitle                                                                    NaN
# Icon URL                      https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# Average User Rating                                                         4.0
# User Rating Count                                                        3553.0
# Price                                                                      2.99
# In-app Purchases                                                            NaN
# Description                   Join over 21,000,000 of our fans and download ...
# Developer                                              Mighty Mighty Good Games
# Age Rating                                                                   4+
# Languages                     DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...
# Size                                                                 15853568.0
# Primary Genre                                                             Games
# Genres                                                  Games, Strategy, Puzzle
# Original Release Date                                                11/07/2008
# Current Version Release Date                                         30/05/2017
#
#                                                                           1      \
# URL                           https://apps.apple.com/us/app/reversi/id284926400
# ID                                                                    284926400
# Name                                                                    Reversi
# Subtitle                                                                    NaN
# Icon URL                      https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# Average User Rating                                                         3.5
# User Rating Count                                                         284.0
# Price                                                                      1.99
# In-app Purchases                                                            NaN
# Description                   The classic game of Reversi, also known as Oth...
# Developer                                                      Kiss The Machine
# Age Rating                                                                   4+
# Languages                                                                    EN
# Size                                                                 12328960.0
# Primary Genre                                                             Games
# Genres                                                   Games, Strategy, Board
# Original Release Date                                                11/07/2008
# Current Version Release Date                                         17/05/2018
#
#                                                                           2      \
# URL                           https://apps.apple.com/us/app/morocco/id284946595
# ID                                                                    284946595
# Name                                                                    Morocco
# Subtitle                                                                    NaN
# Icon URL                      https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# Average User Rating                                                         3.0
# User Rating Count                                                        8376.0
# Price                                                                       0.0
# In-app Purchases                                                            NaN
# Description                   Play the classic strategy game Othello (also k...
# Developer                                                           Bayou Games
# Age Rating                                                                   4+
# Languages                                                                    EN
# Size                                                                   674816.0
# Primary Genre                                                             Games
# Genres                                                   Games, Board, Strategy
# Original Release Date                                                11/07/2008
# Current Version Release Date                                          5/09/2017
#
#                                                                           3      \
# URL                           https://apps.apple.com/us/app/sudoku-free/id28...
# ID                                                                    285755462
# Name                                                              Sudoku (Free)
# Subtitle                                                                    NaN
# Icon URL                      https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# Average User Rating                                                         3.5
# User Rating Count                                                      190394.0
# Price                                                                       0.0
# In-app Purchases                                                            NaN
# Description                   Top 100 free app for over a year.\nRated "Best...
# Developer                                              Mighty Mighty Good Games
# Age Rating                                                                   4+
# Languages                     DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...
# Size                                                                 21552128.0
# Primary Genre                                                             Games
# Genres                                                  Games, Strategy, Puzzle
# Original Release Date                                                23/07/2008
# Current Version Release Date                                         30/05/2017
#
#                                                                           4      \
# URL                           https://apps.apple.com/us/app/senet-deluxe/id2...
# ID                                                                    285831220
# Name                                                               Senet Deluxe
# Subtitle                                                                    NaN
# Icon URL                      https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# Average User Rating                                                         3.5
# User Rating Count                                                          28.0
# Price                                                                      2.99
# In-app Purchases                                                            NaN
# Description                   "Senet Deluxe - The Ancient Game of Life and A...
# Developer                                                       RoGame Software
# Age Rating                                                                   4+
# Languages                     DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...
# Size                                                                 34689024.0
# Primary Genre                                                             Games
# Genres                                        Games, Strategy, Board, Education
# Original Release Date                                                18/07/2008
# Current Version Release Date                                         22/07/2018
#
#                                                                           5      \
# URL                           https://apps.apple.com/us/app/sudoku-classic-n...
# ID                                                                    286210009
# Name                                             Sudoku - Classic number puzzle
# Subtitle                                                Original brain training
# Icon URL                      https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# Average User Rating                                                         3.0
# User Rating Count                                                          47.0
# Price                                                                       0.0
# In-app Purchases                                                           1.99
# Description                   Sudoku will tease your brain, challenge you or...
# Developer                                                       OutOfTheBit Ltd
# Age Rating                                                                   4+
# Languages                                                                    EN
# Size                                                                 48672768.0
# Primary Genre                                                             Games
# Genres                                   Games, Entertainment, Strategy, Puzzle
# Original Release Date                                                30/07/2008
# Current Version Release Date                                         29/04/2019
#
#                                                                           6      \
# URL                           https://apps.apple.com/us/app/gravitation/id28...
# ID                                                                    286313771
# Name                                                                Gravitation
# Subtitle                                                                    NaN
# Icon URL                      https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# Average User Rating                                                         2.5
# User Rating Count                                                          35.0
# Price                                                                       0.0
# In-app Purchases                                                            NaN
# Description                   "Gravitation is a new implementation of the pu...
# Developer                                                         Robert Farnum
# Age Rating                                                                   4+
# Languages                                                                   NaN
# Size                                                                  6328320.0
# Primary Genre                                                             Games
# Genres                                   Games, Entertainment, Puzzle, Strategy
# Original Release Date                                                30/07/2008
# Current Version Release Date                                         14/11/2013
#
#                                                                           7      \
# URL                            https://apps.apple.com/us/app/colony/id286363959
# ID                                                                    286363959
# Name                                                                     Colony
# Subtitle                                                                    NaN
# Icon URL                      https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# Average User Rating                                                         2.5
# User Rating Count                                                         125.0
# Price                                                                      0.99
# In-app Purchases                                                            NaN
# Description                   "50 levels of addictive puzzling strategy fun!...
# Developer                                                          Chris Haynes
# Age Rating                                                                   4+
# Languages                                                                    EN
# Size                                                                 64333824.0
# Primary Genre                                                             Games
# Genres                                                   Games, Strategy, Board
# Original Release Date                                                 3/08/2008
# Current Version Release Date                                          3/10/2018
#
#                                                                           8      \
# URL                             https://apps.apple.com/us/app/carte/id286566987
# ID                                                                    286566987
# Name                                                                      Carte
# Subtitle                                                                    NaN
# Icon URL                      https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# Average User Rating                                                         2.5
# User Rating Count                                                          44.0
# Price                                                                       0.0
# In-app Purchases                                                            NaN
# Description                   "Jeu simple qui consiste \xe0 trouver comment ...
# Developer                                                  Jean-Francois Pautex
# Age Rating                                                                   4+
# Languages                                                                    FR
# Size                                                                  2657280.0
# Primary Genre                                                             Games
# Genres                                    Games, Strategy, Board, Entertainment
# Original Release Date                                                 3/08/2008
# Current Version Release Date                                         23/11/2017
#
#                                                                           9      \
# URL                           https://apps.apple.com/us/app/barrels-o-fun/id...
# ID                                                                    286682679
# Name                                                           "Barrels O' Fun"
# Subtitle                                                                    NaN
# Icon URL                      https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# Average User Rating                                                         2.5
# User Rating Count                                                         184.0
# Price                                                                       0.0
# In-app Purchases                                                            NaN
# Description                   Barrels O\u2019 Fun is a simple but challengin...
# Developer                                                              BesqWare
# Age Rating                                                                   4+
# Languages                                                                    EN
# Size                                                                  1466515.0
# Primary Genre                                                             Games
# Genres                                                  Games, Casual, Strategy
# Original Release Date                                                 1/08/2008
# Current Version Release Date                                          1/08/2008
#
#                               ...  \
# URL                           ...
# ID                            ...
# Name                          ...
# Subtitle                      ...
# Icon URL                      ...
# Average User Rating           ...
# User Rating Count             ...
# Price                         ...
# In-app Purchases              ...
# Description                   ...
# Developer                     ...
# Age Rating                    ...
# Languages                     ...
# Size                          ...
# Primary Genre                 ...
# Genres                        ...
# Original Release Date         ...
# Current Version Release Date  ...
#
#                                                                           16997  \
# URL                           https://apps.apple.com/us/app/stars-merged/id1...
# ID                                                                   1474600038
# Name                                                               Stars Merged
# Subtitle                                         Merge stars to achieve results
# Icon URL                      https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# Average User Rating                                                         NaN
# User Rating Count                                                           NaN
# Price                                                                       0.0
# In-app Purchases                                                            NaN
# Description                   Stars Merged is our newest puzzle game that yo...
# Developer                                                        Mucahid Atakul
# Age Rating                                                                   4+
# Languages                                                                    EN
# Size                                                                107346944.0
# Primary Genre                                                             Games
# Genres                                                  Games, Puzzle, Strategy
# Original Release Date                                                30/07/2019
# Current Version Release Date                                         30/07/2019
#
#                                                                           16998  \
# URL                           https://apps.apple.com/us/app/acrobatic-animal...
# ID                                                                   1474601590
# Name                                                       Acrobatic Animals 3D
# Subtitle                                              Tumble through the hills!
# Icon URL                      https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# Average User Rating                                                         NaN
# User Rating Count                                                           NaN
# Price                                                                       0.0
# In-app Purchases                                                            NaN
# Description                   Test your skills in the most fun and challengi...
# Developer                                                      Nguyen Manh Kiem
# Age Rating                                                                   4+
# Languages                                                                    EN
# Size                                                                239190016.0
# Primary Genre                                                             Games
# Genres                                   Games, Entertainment, Strategy, Casual
# Original Release Date                                                30/07/2019
# Current Version Release Date                                         30/07/2019
#
#                                                                           16999  \
# URL                           https://apps.apple.com/us/app/number-puzzle-20...
# ID                                                                   1474605652
# Name                                                  Number Puzzle : 2048 Saga
# Subtitle                                            Merge Numbers - Block Stack
# Icon URL                      https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# Average User Rating                                                         NaN
# User Rating Count                                                           NaN
# Price                                                                       0.0
# In-app Purchases                                                            NaN
# Description                   Welcome to the fun world of numbers. You will ...
# Developer                                                           Zhigang Pei
# Age Rating                                                                   4+
# Languages                                                                    EN
# Size                                                                 70034432.0
# Primary Genre                                                             Games
# Genres                                   Games, Entertainment, Casual, Strategy
# Original Release Date                                                30/07/2019
# Current Version Release Date                                         30/07/2019
#
#                                                                           17000  \
# URL                           https://apps.apple.com/us/app/super-kid/id1474...
# ID                                                                   1474608803
# Name                                                                  Super kid
# Subtitle                                                                    NaN
# Icon URL                      https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# Average User Rating                                                         NaN
# User Rating Count                                                           NaN
# Price                                                                       NaN
# In-app Purchases                                                            NaN
# Description                   \xc7ok e\u011flenceli k\xfc\xe7\xfck oyun, biz...
# Developer                                                          Karla Abbado
# Age Rating                                                                   4+
# Languages                                                                EN, ZH
# Size                                                                 11404288.0
# Primary Genre                                                             Games
# Genres                                                  Games, Casual, Strategy
# Original Release Date                                                16/08/2019
# Current Version Release Date                                         16/08/2019
#
#                                                                           17001  \
# URL                           https://apps.apple.com/us/app/lava-island-adve...
# ID                                                                   1474611467
# Name                                                      Lava Island Adventure
# Subtitle                                                                    NaN
# Icon URL                      https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# Average User Rating                                                         NaN
# User Rating Count                                                           NaN
# Price                                                                       NaN
# In-app Purchases                                                            NaN
# Description                   Som ung och modig krigare gick han in i Lava\x...
# Developer                                                          Miller Peggy
# Age Rating                                                                   9+
# Languages                                                                EN, ZH
# Size                                                                 21191680.0
# Primary Genre                                                             Games
# Genres                                               Games, Strategy, Adventure
# Original Release Date                                                31/08/2019
# Current Version Release Date                                         31/08/2019
#
#                                                                           17002  \
# URL                           https://apps.apple.com/us/app/stack-puzzle-ris...
# ID                                                                   1474626442
# Name                                                  Stack Puzzle : Rise Tower
# Subtitle                                         Blast the cubes, solve puzzle!
# Icon URL                      https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# Average User Rating                                                         NaN
# User Rating Count                                                           NaN
# Price                                                                       0.0
# In-app Purchases                                                            NaN
# Description                   The goal is very simple, move the square horiz...
# Developer                                                           Zhigang Pei
# Age Rating                                                                   4+
# Languages                                                                    EN
# Size                                                                 64795648.0
# Primary Genre                                                             Games
# Genres                                   Games, Entertainment, Casual, Strategy
# Original Release Date                                                30/07/2019
# Current Version Release Date                                         30/07/2019
#
#                                                                           17003  \
# URL                           https://apps.apple.com/us/app/eachother/id1474...
# ID                                                                   1474919257
# Name                                                                  EachOther
# Subtitle                                                                    NaN
# Icon URL                      https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# Average User Rating                                                         NaN
# User Rating Count                                                           NaN
# Price                                                                       0.0
# In-app Purchases                                                            NaN
# Description                   Collect a score while you play!!\n\nBy linking...
# Developer                                                         Sultan Shindi
# Age Rating                                                                   4+
# Languages                                                                    EN
# Size                                                                110341120.0
# Primary Genre                                                             Games
# Genres                                                  Games, Family, Strategy
# Original Release Date                                                 1/08/2019
# Current Version Release Date                                          1/08/2019
#
#                                                                           17004  \
# URL                           https://apps.apple.com/us/app/rabbit-vs-tortoi...
# ID                                                                   1474962324
# Name                                                         Rabbit Vs Tortoise
# Subtitle                                                                    NaN
# Icon URL                      https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# Average User Rating                                                         NaN
# User Rating Count                                                           NaN
# Price                                                                       0.0
# In-app Purchases                                                            NaN
# Description                   "Rabbit Vs Tortoise is chess type cool simple ...
# Developer                                                         Vishal Baldha
# Age Rating                                                                   4+
# Languages                                                                    EN
# Size                                                                 23207936.0
# Primary Genre                                                             Games
# Genres                                                          Games, Strategy
# Original Release Date                                                 3/08/2019
# Current Version Release Date                                          3/08/2019
#
#                                                                           17005  \
# URL                           https://apps.apple.com/us/app/fatall/id1474963671
# ID                                                                   1474963671
# Name                                                                     FaTaLL
# Subtitle                                                       Most fun game!!!
# Icon URL                      https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# Average User Rating                                                         NaN
# User Rating Count                                                           NaN
# Price                                                                       0.0
# In-app Purchases                                              9.99, 49.99, 3.99
# Description                   Upgrade your character and use your skills to ...
# Developer                                                          Tayrem Games
# Age Rating                                                                   4+
# Languages                                                                    EN
# Size                                                                196750336.0
# Primary Genre                                                             Games
# Genres                                                  Games, Strategy, Action
# Original Release Date                                                 1/08/2019
# Current Version Release Date                                          1/08/2019
#
#                                                                           17006
# URL                           https://apps.apple.com/us/app/the-three-kingdo...
# ID                                                                   1475076711
# Name                                                   The Three Kingdoms :Bomb
# Subtitle                                                                    NaN
# Icon URL                      https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# Average User Rating                                                         NaN
# User Rating Count                                                           NaN
# Price                                                                       0.0
# In-app Purchases                                                            NaN
# Description                   The protagonist uses the method of placing a b...
# Developer                                                          ming bo tang
# Age Rating                                                                   4+
# Languages                                                                EN, ZH
# Size                                                                 22952960.0
# Primary Genre                                                             Games
# Genres                                                  Games, Strategy, Puzzle
# Original Release Date                                                 2/08/2019
# Current Version Release Date                                          2/08/2019
#
# [18 rows x 17007 columns]

# %%
df = df_raw.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17007 entries, 0 to 17006
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   URL                           17007 non-null  object
#  1   ID                            17007 non-null  int64
#  2   Name                          17007 non-null  object
#  3   Subtitle                      5261 non-null   object
#  4   Icon URL                      17007 non-null  object
#  5   Average User Rating           7561 non-null   float64
#  6   User Rating Count             7561 non-null   float64
#  7   Price                         16983 non-null  float64
#  8   In-app Purchases              7683 non-null   object
#  9   Description                   17007 non-null  object
#  10  Developer                     17007 non-null  object
#  11  Age Rating                    17007 non-null  object
#  12  Languages                     16947 non-null  object
#  13  Size                          17006 non-null  float64
#  14  Primary Genre                 17007 non-null  object
#  15  Genres                        17007 non-null  object
#  16  Original Release Date         17007 non-null  object
#  17  Current Version Release Date  17007 non-null  object
# dtypes: float64(4), int64(1), object(13)
# memory usage: 2.3+ MB

# %%
df = df.drop(columns= ['URL', 'Icon URL', 'Subtitle', 'Description','In-app Purchases' ])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-5422e84e8db3> in <module>()
# ----> 1 df = df.drop(columns= ['URL', 'Icon URL', 'Subtitle', 'Description','In-app Purchases' ])
#       2 df.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['URL' 'Icon URL' 'Subtitle' 'Description' 'In-app Purchases'] not found in axis"

# %%
df.head()
# Out:
#           ID           Name  Average User Rating  User Rating Count  Price  \
# 0  284921427         Sudoku                  4.0             3553.0   2.99
# 1  284926400        Reversi                  3.5              284.0   1.99
# 2  284946595        Morocco                  3.0             8376.0   0.00
# 3  285755462  Sudoku (Free)                  3.5           190394.0   0.00
# 4  285831220   Senet Deluxe                  3.5               28.0   2.99
#
#                   Developer Age Rating  \
# 0  Mighty Mighty Good Games         4+
# 1          Kiss The Machine         4+
# 2               Bayou Games         4+
# 3  Mighty Mighty Good Games         4+
# 4           RoGame Software         4+
#
#                                            Languages        Size  \
# 0  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...  15853568.0
# 1                                                 EN  12328960.0
# 2                                                 EN    674816.0
# 3  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...  21552128.0
# 4  DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...  34689024.0
#
#   Primary Genre                             Genres Original Release Date  \
# 0         Games            Games, Strategy, Puzzle            11/07/2008
# 1         Games             Games, Strategy, Board            11/07/2008
# 2         Games             Games, Board, Strategy            11/07/2008
# 3         Games            Games, Strategy, Puzzle            23/07/2008
# 4         Games  Games, Strategy, Board, Education            18/07/2008
#
#   Current Version Release Date
# 0                   30/05/2017
# 1                   17/05/2018
# 2                    5/09/2017
# 3                   30/05/2017
# 4                   22/07/2018

# %%
df = df.set_index('ID')
df.head()
# Out:
#                     Name  Average User Rating  User Rating Count  Price  \
# ID
# 284921427         Sudoku                  4.0             3553.0   2.99
# 284926400        Reversi                  3.5              284.0   1.99
# 284946595        Morocco                  3.0             8376.0   0.00
# 285755462  Sudoku (Free)                  3.5           190394.0   0.00
# 285831220   Senet Deluxe                  3.5               28.0   2.99
#
#                           Developer Age Rating  \
# ID
# 284921427  Mighty Mighty Good Games         4+
# 284926400          Kiss The Machine         4+
# 284946595               Bayou Games         4+
# 285755462  Mighty Mighty Good Games         4+
# 285831220           RoGame Software         4+
#
#                                                    Languages        Size  \
# ID
# 284921427  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...  15853568.0
# 284926400                                                 EN  12328960.0
# 284946595                                                 EN    674816.0
# 285755462  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...  21552128.0
# 285831220  DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...  34689024.0
#
#           Primary Genre                             Genres  \
# ID
# 284921427         Games            Games, Strategy, Puzzle
# 284926400         Games             Games, Strategy, Board
# 284946595         Games             Games, Board, Strategy
# 285755462         Games            Games, Strategy, Puzzle
# 285831220         Games  Games, Strategy, Board, Education
#
#           Original Release Date Current Version Release Date
# ID
# 284921427            11/07/2008                   30/05/2017
# 284926400            11/07/2008                   17/05/2018
# 284946595            11/07/2008                    5/09/2017
# 285755462            23/07/2008                   30/05/2017
# 285831220            18/07/2008                   22/07/2018

# %%
df.describe().T
# Out:
#                        count          mean           std      min         25%  \
# Average User Rating   7561.0  4.060905e+00  7.514275e-01      1.0         3.5
# User Rating Count     7561.0  3.306531e+03  4.232256e+04      5.0        12.0
# Price                16983.0  8.134187e-01  7.835732e+00      0.0         0.0
# Size                 17006.0  1.157064e+08  2.036477e+08  51328.0  22950144.0
#
#                             50%          75%           max
# Average User Rating         4.5          4.5  5.000000e+00
# User Rating Count          46.0        309.0  3.032734e+06
# Price                       0.0          0.0  1.799900e+02
# Size                 56768954.0  133027072.0  4.005591e+09

# %%
df.describe(include=['object'])
# Out:
#              Name                                   Developer Age Rating  \
# count       17007                                       17007      17007
# unique      16847                                        8693          4
# top     Additions  Tapps Tecnologia da Informa\xe7\xe3o Ltda.         4+
# freq            2                                         123      11806
#
#        Languages Primary Genre                   Genres Original Release Date  \
# count      16947         17007                    17007                 17007
# unique       990            21                     1004                  3084
# top           EN         Games  Games, Strategy, Puzzle             2/09/2016
# freq       12467         16286                      778                    75
#
#        Current Version Release Date
# count                         17007
# unique                         2512
# top                       1/08/2019
# freq                            118

# %%
df.describe(include=['object']).T
# Out:
#                               count unique  \
# Name                          17007  16847
# Developer                     17007   8693
# Age Rating                    17007      4
# Languages                     16947    990
# Primary Genre                 17007     21
# Genres                        17007   1004
# Original Release Date         17007   3084
# Current Version Release Date  17007   2512
#
#                                                                      top  \
# Name                                                           Additions
# Developer                     Tapps Tecnologia da Informa\xe7\xe3o Ltda.
# Age Rating                                                            4+
# Languages                                                             EN
# Primary Genre                                                      Games
# Genres                                           Games, Strategy, Puzzle
# Original Release Date                                          2/09/2016
# Current Version Release Date                                   1/08/2019
#
#                                freq
# Name                              2
# Developer                       123
# Age Rating                    11806
# Languages                     12467
# Primary Genre                 16286
# Genres                          778
# Original Release Date            75
# Current Version Release Date    118

# %%
df.columns
# Out:
# Index(['Name', 'Average User Rating', 'User Rating Count', 'Price',
#        'Developer', 'Age Rating', 'Languages', 'Size', 'Primary Genre',
#        'Genres', 'Original Release Date', 'Current Version Release Date'],
#       dtype='object')

# %%
df.columns = [col.lower().replace(' ', '_') for col in df.columns]

# %%
df.columns
# Out:
# Index(['name', 'average_user_rating', 'user_rating_count', 'price',
#        'developer', 'age_rating', 'languages', 'size', 'primary_genre',
#        'genres', 'original_release_date', 'current_version_release_date'],
#       dtype='object')

# %%
df.primary_genre.value_counts()
# Out:
# Games                16286
# Education              222
# Entertainment          198
# Utilities               77
# Sports                  60
# Reference               32
# Stickers                29
# Finance                 18
# Business                16
# Productivity            15
# Lifestyle               10
# Book                     9
# Social Networking        9
# News                     7
# Health & Fitness         5
# Food & Drink             4
# Music                    3
# Navigation               3
# Medical                  2
# Travel                   1
# Shopping                 1
# Name: primary_genre, dtype: int64

# %%
df.primary_genre.value_counts().nlargest(5).index
# Out:
# Index(['Games', 'Education', 'Entertainment', 'Utilities', 'Sports'], dtype='object')

# %%
df.age_rating.value_counts()
# Out:
# 4+     11806
# 9+      2481
# 12+     2055
# 17+      665
# Name: age_rating, dtype: int64

# %%
type(df.age_rating.value_counts())
# Out:
# pandas.core.series.Series

# %%
import seaborn as sns
sns.set()
_ =df.age_rating.value_counts().plot(kind='bar')

# %%
df.price.value_counts().plot(kind = 'bar')

# %%
df.average_user_rating.value_counts()
# Out:
# 4.5    2861
# 4.0    1722
# 5.0     990
# 3.5     925
# 3.0     514
# 2.5     317
# 2.0     158
# 1.5      60
# 1.0      14
# Name: average_user_rating, dtype: int64

# %%
df.languages.value_counts()
# Out:
# EN                                                                            12467
# EN, ZH                                                                          354
# CS, NL, EN, FR, DE, IT, JA, KO, PL, PT, RU, ZH, ES, SV, ZH, TR                  277
# EN, ZH, ZH                                                                      248
# EN, DE                                                                          147
#                                                                               ...
# DA, NL, EN, FI, FR, DE, IT, JA, KO, NO, PL, PT, RU, ZH, ES, SV, ZH, TR, UK        1
# EN, FR, IT, JA, KO, PT, RU, ES, TR                                                1
# DA, NL, EN, FR, DE, IT, NB, PL, PT, ZH, ES, SV, ZH, TR                            1
# EN, PT, ZH                                                                        1
# AR, NL, EN, FR, DE, ID, IT, JA, KO, PT, RU, ZH, ES, SV, TH, ZH, TR, VI            1
# Name: languages, Length: 990, dtype: int64

# %%
df.languages.str.split(', ')
# Out:
# ID
# 284921427     [DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, P...
# 284926400                                                  [EN]
# 284946595                                                  [EN]
# 285755462     [DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, P...
# 285831220     [DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, R...
#                                     ...
# 1474626442                                                 [EN]
# 1474919257                                                 [EN]
# 1474962324                                                 [EN]
# 1474963671                                                 [EN]
# 1475076711                                             [EN, ZH]
# Name: languages, Length: 17007, dtype: object

# %%
df.languages.str.split(', ').str.len()
df.head()
# Out:
#                     name  average_user_rating  user_rating_count  price  \
# ID
# 284921427         Sudoku                  4.0             3553.0   2.99
# 284926400        Reversi                  3.5              284.0   1.99
# 284946595        Morocco                  3.0             8376.0   0.00
# 285755462  Sudoku (Free)                  3.5           190394.0   0.00
# 285831220   Senet Deluxe                  3.5               28.0   2.99
#
#                           developer age_rating  \
# ID
# 284921427  Mighty Mighty Good Games         4+
# 284926400          Kiss The Machine         4+
# 284946595               Bayou Games         4+
# 285755462  Mighty Mighty Good Games         4+
# 285831220           RoGame Software         4+
#
#                                                    languages        size  \
# ID
# 284921427  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...  15853568.0
# 284926400                                                 EN  12328960.0
# 284946595                                                 EN    674816.0
# 285755462  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...  21552128.0
# 285831220  DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...  34689024.0
#
#           primary_genre                             genres  \
# ID
# 284921427         Games            Games, Strategy, Puzzle
# 284926400         Games             Games, Strategy, Board
# 284946595         Games             Games, Board, Strategy
# 285755462         Games            Games, Strategy, Puzzle
# 285831220         Games  Games, Strategy, Board, Education
#
#           original_release_date current_version_release_date
# ID
# 284921427            11/07/2008                   30/05/2017
# 284926400            11/07/2008                   17/05/2018
# 284946595            11/07/2008                    5/09/2017
# 285755462            23/07/2008                   30/05/2017
# 285831220            18/07/2008                   22/07/2018

# %%
df.languages.str.split(', ').str.len().value_counts()
# Out:
# 1.0      12566
# 2.0       1102
# 3.0        495
# 16.0       316
# 4.0        261
# 5.0        247
# 6.0        220
# 25.0       171
# 9.0        154
# 11.0       147
# 8.0        142
# 7.0        140
# 10.0       140
# 31.0       133
# 12.0        91
# 21.0        77
# 14.0        64
# 13.0        64
# 15.0        54
# 17.0        37
# 30.0        35
# 19.0        34
# 32.0        34
# 33.0        33
# 22.0        31
# 18.0        24
# 46.0        20
# 26.0        18
# 20.0        14
# 24.0        13
# 23.0        11
# 27.0        11
# 28.0         9
# 29.0         8
# 45.0         6
# 44.0         5
# 65.0         4
# 42.0         3
# 43.0         3
# 36.0         2
# 49.0         2
# 48.0         1
# 66.0         1
# 35.0         1
# 34.0         1
# 111.0        1
# 76.0         1
# Name: languages, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17007 entries, 284921427 to 1475076711
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          17007 non-null  object
#  1   average_user_rating           7561 non-null   float64
#  2   user_rating_count             7561 non-null   float64
#  3   price                         16983 non-null  float64
#  4   developer                     17007 non-null  object
#  5   age_rating                    17007 non-null  object
#  6   languages                     16947 non-null  object
#  7   size                          17006 non-null  float64
#  8   primary_genre                 17007 non-null  object
#  9   genres                        17007 non-null  object
#  10  original_release_date         17007 non-null  object
#  11  current_version_release_date  17007 non-null  object
# dtypes: float64(4), object(8)
# memory usage: 1.7+ MB

# %%
df.average_user_rating.value_counts()
# Out:
# 4.5    2861
# 4.0    1722
# 5.0     990
# 3.5     925
# 3.0     514
# 2.5     317
# 2.0     158
# 1.5      60
# 1.0      14
# Name: average_user_rating, dtype: int64

# %%
df.average_user_rating.value_counts(dropna= False)
# Out:
# NaN    9446
# 4.5    2861
# 4.0    1722
# 5.0     990
# 3.5     925
# 3.0     514
# 2.5     317
# 2.0     158
# 1.5      60
# 1.0      14
# Name: average_user_rating, dtype: int64

# %%
df.isnull()
# Out:
#              name  average_user_rating  user_rating_count  price  developer  \
# ID
# 284921427   False                False              False  False      False
# 284926400   False                False              False  False      False
# 284946595   False                False              False  False      False
# 285755462   False                False              False  False      False
# 285831220   False                False              False  False      False
# ...           ...                  ...                ...    ...        ...
# 1474626442  False                 True               True  False      False
# 1474919257  False                 True               True  False      False
# 1474962324  False                 True               True  False      False
# 1474963671  False                 True               True  False      False
# 1475076711  False                 True               True  False      False
#
#             age_rating  languages   size  primary_genre  genres  \
# ID
# 284921427        False      False  False          False   False
# 284926400        False      False  False          False   False
# 284946595        False      False  False          False   False
# 285755462        False      False  False          False   False
# 285831220        False      False  False          False   False
# ...                ...        ...    ...            ...     ...
# 1474626442       False      False  False          False   False
# 1474919257       False      False  False          False   False
# 1474962324       False      False  False          False   False
# 1474963671       False      False  False          False   False
# 1475076711       False      False  False          False   False
#
#             original_release_date  current_version_release_date
# ID
# 284921427                   False                         False
# 284926400                   False                         False
# 284946595                   False                         False
# 285755462                   False                         False
# 285831220                   False                         False
# ...                           ...                           ...
# 1474626442                  False                         False
# 1474919257                  False                         False
# 1474962324                  False                         False
# 1474963671                  False                         False
# 1475076711                  False                         False
#
# [17007 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# name                               0
# average_user_rating             9446
# user_rating_count               9446
# price                             24
# developer                          0
# age_rating                         0
# languages                         60
# size                               1
# primary_genre                      0
# genres                             0
# original_release_date              0
# current_version_release_date       0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# name                            0
# average_user_rating             0
# user_rating_count               0
# price                           0
# developer                       0
# age_rating                      0
# languages                       0
# size                            0
# primary_genre                   0
# genres                          0
# original_release_date           0
# current_version_release_date    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7537 entries, 284921427 to 1474461379
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          7537 non-null   object
#  1   average_user_rating           7537 non-null   float64
#  2   user_rating_count             7537 non-null   float64
#  3   price                         7537 non-null   float64
#  4   developer                     7537 non-null   object
#  5   age_rating                    7537 non-null   object
#  6   languages                     7537 non-null   object
#  7   size                          7537 non-null   float64
#  8   primary_genre                 7537 non-null   object
#  9   genres                        7537 non-null   object
#  10  original_release_date         7537 non-null   object
#  11  current_version_release_date  7537 non-null   object
# dtypes: float64(4), object(8)
# memory usage: 765.5+ KB
